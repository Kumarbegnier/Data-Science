# %% [markdown]
# <a href="https://colab.research.google.com/github/Kumarbegnier/Data-Science/blob/main/recursive_sum__natural_num.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def cal_sum(n):
    if (n == 0):
        return 0
    return cal_sum(n-1) + n

print("recursive sum of the n is", cal_sum(10))
# Out:
# recursive sum of the n is 55
