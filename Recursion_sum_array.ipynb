# %% [markdown]
# <a href="https://colab.research.google.com/github/Kumarbegnier/Data-Science/blob/main/Recursion_sum_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🔹 **Problem Statement**
#
# Find the **sum of all elements** in an array using recursion.

# %% [markdown]
# 🔹 **Recursive Approach** (Concept)
#
# To sum an array recursively:
#
# **Base Case** → When the array has no elements, return 0
#
# **Recursive Case** →
# sum = first_element + sum(remaining_elements)

# %%
def sum_array(arr, n):
    if n == 0: #base case
        return 0
    return n + sum_array(arr[1:], n-1) #recursive

arr = [1,2,3,4,5,6,7,8,9]
n = len(arr)

print(sum_array(arr, n))
# Out:
# 45
