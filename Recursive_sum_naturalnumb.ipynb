# %% [markdown]
# <a href="https://colab.research.google.com/github/Kumarbegnier/Data-Science/blob/main/Recursive_sum_naturalnumb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sum_natural(n):
    if n == 1:          # base case
        return 1
    else:
        return n + sum_natural(n - 1)

# Example
print("Sum of first", n, "natural numbers is:", sum_natural(10))
# Out:
# Sum of first 10 natural numbers is: 55
